# %%
pip install tabula-py
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install camelot-py
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tabula

# %%
file1 = "/Users/mariyammukhumova/Documents/A1.pdf"

# %%
tables = tabula.read_pdf(file1, pages = '6', multiple_tables=False)
tables[0]
# Out:
#         Unnamed: 0  Unnamed: 1     SS2    SS5    SS6    SS7   SS10   SS11  \
# 0              NaN         NaN     (A)    (A)    (B)   (BA)   (BA)   (BA)
# 1   Major elements         NaN  (wt.%)    NaN    NaN    NaN    NaN    NaN
# 2             SiO2         NaN   57.13  59.18  49.38  53.08  52.46  54.72
# 3             TiO2         NaN    1.15   0.96   1.79   1.59   1.68   1.24
# 4            Al2O3         NaN   17.41  16.97  16.81  16.65  16.72  16.74
# 5         Fe 2O3 ∗         NaN    7.16   6.17   8.94   8.62   7.65   8.52
# 6              MnO         NaN    0.15   0.15   0.15   0.13   0.13   0.16
# 7              MgO         NaN    2.95   2.69   8.45   4.95   5.51   6.38
# 8              CaO         NaN    5.44   5.52   7.76   6.82   7.21   5.59
# 9             Na2O         NaN    4.26   4.17   3.51   4.12   4.32   3.45
# 10             K2O         NaN    1.97   2.14   1.15   1.25   1.79   1.38
# 11            P2O5         NaN    0.24   0.28   0.27   0.35   0.43   0.21
# ...

# %%
tables[0].to_csv('file.csv', index = False)

# %%
import camelot

# %%
import os
os.path.abspath("/Users/mariyammukhumova/Documents/")
from tabula import wrapper
tables = wrapper.read_pdf("A1.pdf",multiple_tables=True,pages='all')

i=1
for table in tables:
    table.to_excel('output'+str(i)+'.xlsx',index=False)
    print(i)
    i=i+1
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-fed01729ef0a> in <module>
#       1 import os
#       2 os.path.abspath("/Users/mariyammukhumova/Documents/")
# ----> 3 from tabula import wrapper
#       4 tables = wrapper.read_pdf("A1.pdf",multiple_tables=True,pages='all')
#       5
#
# ImportError: cannot import name 'wrapper' from 'tabula' (/Users/mariyammukhumova/opt/anaconda3/lib/python3.8/site-packages/tabula/__init__.py)
